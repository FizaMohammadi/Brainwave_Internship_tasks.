# %%
# Importing necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Step 1: Create an enriched dataset

# Step 1: Create an enriched dataset

data = {
    "Date": pd.date_range(start="2024-10-01", periods=20),
    "Invoice ID": [f"INV{1000 + i}" for i in range(20)],
    "Customer ID": [f"CUST{i%5}" for i in range(20)],  # Repeating customers
    "Product": ["Mobiles", "Laptop", "Refrigerator", "Car"] * 5,
    "Category": ["Electronics", "Gadget", "Home", "Automobile"] * 5,
    "Price": [25000, 70000, 50000, 800000] * 5,
    "Quantity Sold": [10, 20, 15, 8, 12, 18, 5, 22, 14, 11, 9, 7, 30, 25, 6, 13, 19, 17, 11, 2],
    "Region": ["North", "South", "East", "West"] * 5,
    "Salesperson": ["Alice", "Bob", "Charlie", "David", "Emily"] * 4,
    "Discount": np.random.randint(10, 25, size=20),
    "Shipping Cost": np.random.uniform(5, 20, size=20),
    "Profit Margin": np.random.uniform(0.2, 0.4, size=20),
    "Warranty Period (Years)": [2, 3, 1, 5] * 5,
    "Brand": ["Samsung", "Dell", "LG", "Toyota"] * 5,
    "Power Consumption (Watts)": [10, 50, 200, 0] * 5,  # Cars usually don’t have this field
    "Battery Life (Hours)": [24, 12, None, None] * 5,  # Not all products have batteries
    "Safety Rating (Out of 5)": [4.5, 4.0, 3.5, 5.0] * 5,
    "Technology/Feature": ["5G Enabled", "AI Powered", "Smart Cooling", "Hybrid"] * 5,
    "Service Centers (Region)": [20, 25, 15, 30] * 5,
}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#          Date Invoice ID Customer ID       Product     Category   Price  \
# 0  2024-10-01    INV1000       CUST0       Mobiles  Electronics   25000
# 1  2024-10-02    INV1001       CUST1        Laptop       Gadget   70000
# 2  2024-10-03    INV1002       CUST2  Refrigerator         Home   50000
# 3  2024-10-04    INV1003       CUST3           Car   Automobile  800000
# 4  2024-10-05    INV1004       CUST4       Mobiles  Electronics   25000
# 5  2024-10-06    INV1005       CUST0        Laptop       Gadget   70000
# 6  2024-10-07    INV1006       CUST1  Refrigerator         Home   50000
# 7  2024-10-08    INV1007       CUST2           Car   Automobile  800000
# 8  2024-10-09    INV1008       CUST3       Mobiles  Electronics   25000
# 9  2024-10-10    INV1009       CUST4        Laptop       Gadget   70000
# 10 2024-10-11    INV1010       CUST0  Refrigerator         Home   50000
# 11 2024-10-12    INV1011       CUST1           Car   Automobile  800000
# ...

# %%
df["Total Sales"]=df["Price"]*df["Quantity Sold"]

# %%
df["Total Sales"].value_counts()
# Out:
# Total Sales
# 250000      2
# 750000      2
# 300000      2
# 5600000     1
# 550000      1
# 1190000     1
# 475000      1
# 10400000    1
# 1750000     1
# 770000      1
# 450000      1
# 1400000     1
# 350000      1
# 17600000    1
# 1260000     1
# 6400000     1
# 1600000     1
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Date', 'Invoice ID', 'Customer ID', 'Product', 'Category', 'Price',
#        'Quantity Sold', 'Region', 'Salesperson', 'Discount', 'Shipping Cost',
#        'Profit Margin', 'Warranty Period (Years)', 'Brand',
#        'Power Consumption (Watts)', 'Battery Life (Hours)',
#        'Safety Rating (Out of 5)', 'Technology/Feature',
#        'Service Centers (Region)', 'Total Sales'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Date                          0
# Invoice ID                    0
# Customer ID                   0
# Product                       0
# Category                      0
# Price                         0
# Quantity Sold                 0
# Region                        0
# Salesperson                   0
# Discount                      0
# Shipping Cost                 0
# Profit Margin                 0
# Warranty Period (Years)       0
# Brand                         0
# Power Consumption (Watts)     0
# Battery Life (Hours)         10
# Safety Rating (Out of 5)      0
# Technology/Feature            0
# Service Centers (Region)      0
# Total Sales                   0
# dtype: int64

# %%
df["Battery Life (Hours)"]=df["Battery Life (Hours)"].fillna(df["Battery Life (Hours)"].mode()[0])

# %%
df.head()
# Out:
#         Date Invoice ID Customer ID       Product     Category   Price  \
# 0 2024-10-01    INV1000       CUST0       Mobiles  Electronics   25000
# 1 2024-10-02    INV1001       CUST1        Laptop       Gadget   70000
# 2 2024-10-03    INV1002       CUST2  Refrigerator         Home   50000
# 3 2024-10-04    INV1003       CUST3           Car   Automobile  800000
# 4 2024-10-05    INV1004       CUST4       Mobiles  Electronics   25000
#
#    Quantity Sold Region Salesperson  Discount  Shipping Cost  Profit Margin  \
# 0             10  North       Alice        16       8.956189       0.388101
# 1             20  South         Bob        19       6.747932       0.335885
# 2             15   East     Charlie        11      12.435022       0.277495
# 3              8   West       David        11      17.764750       0.394276
# 4             12  North       Emily        16      19.223436       0.297872
#
#    Warranty Period (Years)    Brand  Power Consumption (Watts)  \
# ...

# %%
df.isna().sum()
# Out:
# Date                         0
# Invoice ID                   0
# Customer ID                  0
# Product                      0
# Category                     0
# Price                        0
# Quantity Sold                0
# Region                       0
# Salesperson                  0
# Discount                     0
# Shipping Cost                0
# Profit Margin                0
# Warranty Period (Years)      0
# Brand                        0
# Power Consumption (Watts)    0
# Battery Life (Hours)         0
# Safety Rating (Out of 5)     0
# Technology/Feature           0
# Service Centers (Region)     0
# Total Sales                  0
# dtype: int64

# %%
# Calculate total sales by region
total_sales_by_region = df.groupby('Region')['Total Sales'].sum()

# %%
# Visualize the results
plt.figure(figsize=(10, 6))
total_sales_by_region.plot(kind='bar')
plt.title('Total Sales by Region')
plt.xlabel('Region')
plt.ylabel('Total Sales')
plt.show()

# %%
# 2. Top-Selling Products by Category:
# Group by category and sum the quantities sold
top_selling_products = df.groupby(['Category', 'Product'])['Quantity Sold'].sum().sort_values(ascending=False)

# %%
# Print the top 5
print(top_selling_products.head(5))
# Out:
# Category     Product
# Gadget       Laptop          91
# Electronics  Mobiles         85
# Automobile   Car             52
# Home         Refrigerator    46
# Name: Quantity Sold, dtype: int64

# %%
#3. Salesperson Performance:
# Group by salesperson and calculate total sales
salesperson_performance = df.groupby('Salesperson')['Total Sales'].sum()

# Visualize the performance
plt.figure(figsize=(10, 6))
salesperson_performance.plot(kind='bar')
plt.title('Salesperson Performance')
plt.xlabel('Salesperson')
plt.ylabel('Total Sales')
plt.show()

# %%
#4. Product-Wise Profit Margin:
# Group by product and calculate average profit margin
product_profit_margin = df.groupby('Product')['Profit Margin'].mean()

# Visualize the profit margins
plt.figure(figsize=(10, 6))
product_profit_margin.plot(kind='bar')
plt.title('Product-Wise Profit Margin')
plt.xlabel('Product')
plt.ylabel('Average Profit Margin')
plt.show()

# %%
#5. Time Series Analysis:
# The 'Date' column is already the index, no need to set it again
# df.set_index('Date', inplace=True)  # Remove or comment out this line

# Plot the total sales over time
plt.figure(figsize=(10, 6))
df['Total Sales'].plot()
plt.title('Total Sales Over Time')
plt.xlabel('Date')
plt.ylabel('Total Sales')
plt.show()

# %%
import plotly.express as px

# Bar Plot
fig = px.bar(df, x="Region", y="Quantity Sold", color="Region", title="Quantity Sold by Region")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.scatter(
    df,
    x="Price",
    y="Quantity Sold",
    color="Category",
    size="Profit Margin",
    hover_name="Product",
    title="Price vs. Quantity Sold"
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.pie(
    df,
    names="Category",
    values="Quantity Sold",
    title="Sales Distribution by Category",
    hole=0.4  # For a donut chart
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.sunburst(
    df,
    path=["Region", "Salesperson"],
    values="Quantity Sold",
    color="Quantity Sold",
    title="Quantity Sold by Region and Salesperson"
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.histogram(
    df,
    x="Discount",
    nbins=10,
    title="Distribution of Discounts",
    color="Region"
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.head()
# Out:
#         Date Invoice ID Customer ID       Product     Category   Price  \
# 0 2024-10-01    INV1000       CUST0       Mobiles  Electronics   25000
# 1 2024-10-02    INV1001       CUST1        Laptop       Gadget   70000
# 2 2024-10-03    INV1002       CUST2  Refrigerator         Home   50000
# 3 2024-10-04    INV1003       CUST3           Car   Automobile  800000
# 4 2024-10-05    INV1004       CUST4       Mobiles  Electronics   25000
#
#    Quantity Sold Region Salesperson  Discount  Shipping Cost  Profit Margin  \
# 0             10  North       Alice        16       8.956189       0.388101
# 1             20  South         Bob        19       6.747932       0.335885
# 2             15   East     Charlie        11      12.435022       0.277495
# 3              8   West       David        11      17.764750       0.394276
# 4             12  North       Emily        16      19.223436       0.297872
#
#    Warranty Period (Years)    Brand  Power Consumption (Watts)  \
# ...

# %%
fig = px.scatter_3d(
    df,
    x="Price",
    y="Quantity Sold",
    z="Shipping Cost",
    color="Category",
    title="Price vs Quantity Sold vs Shipping Cost"
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.box(
    df,
    x="Product",
    y="Total Sales",  # Changed 'Total sales' to 'Total Sales'
    color="Category",
    title="Price Distribution by Category",
    points="all"  # Show all points as a strip along the box
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Invoice ID', 'Customer ID', 'Product', 'Category', 'Price',
#        'Quantity Sold', 'Region', 'Salesperson', 'Discount', 'Shipping Cost',
#        'Profit Margin', 'Warranty Period (Years)', 'Brand',
#        'Power Consumption (Watts)', 'Battery Life (Hours)',
#        'Safety Rating (Out of 5)', 'Technology/Feature',
#        'Service Centers (Region)', 'Total Sales'],
#       dtype='object')

# %%
plt.figure(figsize=(8, 6))
plt.hist(df["Price"], bins=10, color="skyblue", edgecolor="black")
plt.title("Price Distribution")
plt.xlabel("Total Sales")
plt.ylabel("Frequency")
plt.show()

# %%
# 1. Total Sales by Product
df['Total Sales'] = df['Price'] * df['Quantity Sold']
total_sales_by_product = df.groupby('Product')['Total Sales'].sum()

# 2. Sales by Region
sales_by_region = df.groupby('Region')['Total Sales'].sum()

# 3. Top Selling Products (by quantity sold)
top_selling_products = df.groupby('Product')['Quantity Sold'].sum().sort_values(ascending=False)

# 4. Profit Margin and Discount Analysis
df['Discounted Price'] = df['Price'] - (df['Price'] * df['Discount'] / 100)
profit_margin_vs_discount = df.groupby('Discount')['Profit Margin'].mean()

# 5. Sales Performance by Salesperson
sales_by_salesperson = df.groupby('Salesperson')['Total Sales'].sum()

# 6. Warranty and Product Categories
warranty_by_category = df.groupby('Category')['Warranty Period (Years)'].mean()

# 7. Shipping Costs Analysis
shipping_cost_by_product = df.groupby('Product')['Shipping Cost'].mean()

# Display insights
print("Total Sales by Product:\n", total_sales_by_product)
print("\nSales by Region:\n", sales_by_region)
print("\nTop Selling Products (by Quantity Sold):\n", top_selling_products)
print("\nProfit Margin vs Discount:\n", profit_margin_vs_discount)
print("\nSales by Salesperson:\n", sales_by_salesperson)
print("\nWarranty by Product Category:\n", warranty_by_category)
print("\nShipping Cost by Product:\n", shipping_cost_by_product)
# Out:
# Total Sales by Product:
#  Product
# Car             41600000
# Laptop           6370000
# Mobiles          2125000
# Refrigerator     2300000
# Name: Total Sales, dtype: int64
#
# Sales by Region:
#  Region
# East      2300000
# North     2125000
# South     6370000
# West     41600000
# Name: Total Sales, dtype: int64
#
# Top Selling Products (by Quantity Sold):
#  Product
# Laptop          91
# Mobiles         85
# Car             52
# Refrigerator    46
# Name: Quantity Sold, dtype: int64
#
# Profit Margin vs Discount:
#  Discount
# 11    0.331948
# 15    0.272425
# 16    0.332150
# 17    0.259678
# 18    0.321992
# 19    0.330722
# 20    0.320230
# 21    0.252351
# 24    0.233739
# Name: Profit Margin, dtype: float64
#
# Sales by Salesperson:
#  Salesperson
# Alice      12360000
# Bob         7725000
# Charlie    20290000
# David       9050000
# Emily       2970000
# Name: Total Sales, dtype: int64
#
# Warranty by Product Category:
#  Category
# Automobile     5.0
# ...

# %%
''' 1. Total Sales by Product:
Car leads in total sales by a significant margin, followed by Laptop and Mobiles.
Mobiles and Refrigerators generate lower sales despite being popular in terms of quantity sold.
2. Sales by Region:
West generates the highest total sales, driven by Car sales.
South and East have moderate sales, while North has the lowest.
3. Top Selling Products:
Laptop is the top-selling product by quantity, followed by Mobiles, indicating strong demand in these categories.
4. Profit Margin vs Discount:
Profit margins are relatively consistent across discount levels, with slight dips at higher discounts (e.g., 24% discount has a lower margin).
5. Sales by Salesperson:
Charlie leads in total sales, followed by Alice, indicating their strong performance. Emily has the lowest sales.
6. Warranty by Product Category:
Automobiles offer the longest warranty (5 years), while Home products offer the shortest (1 year), reflecting product durability expectations.
7. Shipping Cost by Product:
Car and Mobiles have the highest shipping costs, while Laptop has the lowest, which could be due to size and weight differences.
These insights provide a snapshot of product performance, regional sales, and potential areas for cost optimization, such as shipping and discount strategies. '''
# Out:
# ' 1. Total Sales by Product:\nCar leads in total sales by a significant margin, followed by Laptop and Mobiles.\nMobiles and Refrigerators generate lower sales despite being popular in terms of quantity sold.\n2. Sales by Region:\nWest generates the highest total sales, driven by Car sales.\nSouth and East have moderate sales, while North has the lowest.\n3. Top Selling Products:\nLaptop is the top-selling product by quantity, followed by Mobiles, indicating strong demand in these categories.\n4. Profit Margin vs Discount:\nProfit margins are relatively consistent across discount levels, with slight dips at higher discounts (e.g., 24% discount has a lower margin).\n5. Sales by Salesperson:\nCharlie leads in total sales, followed by Alice, indicating their strong performance. Emily has the lowest sales.\n6. Warranty by Product Category:\nAutomobiles offer the longest warranty (5 years), while Home products offer the shortest (1 year), reflecting product durability expectations.\n7. Sh
# ...
